# %% [markdown]
# ---
# title: "test"
# author: "YourName"
# format:
#   html:
#     theme: journal  # 可以换成 zephyr, journal, darkly 等
#     toc: true     # 开启目录
#     code-overflow: wrap
# ---

# %% [markdown]
# ::: {.callout-tip}
# 这是一个技巧。非常适合用来放你的“解题思路”。
# :::

# %% [markdown]
# ::: {.callout-note}
# 这是一个提示信息。Quarto 会自动给它加个 ℹ️ 图标。
# :::

# %% [markdown]
# ::: {.callout-warning}
# 注意！这里很容易踩坑。
# :::

# %% [markdown]
# ::: {.callout-important}
# 这是非常重要的内容，一定要看！
# :::

# %% [markdown]
# ::: {.callout-caution}
# 小心驶得万年船。
# :::

# %%
def main():
    print("hello world!")

main()
# Out:
# hello world!

# %%
# quarto render .\test.ipynb
