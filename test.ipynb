# %% [markdown]
# ---
# title: "test"
# author: "YourName"
# format:
#   html:
#     theme: journal  # 可以换成 zephyr, journal, darkly 等
#     toc: true     # 开启目录
#     code-overflow: wrap
# ---

# %% [markdown]
# ::: {.callout-tip}
# 这是一个技巧。非常适合用来放你的“解题思路”。
# :::

# %% [markdown]
# ::: {.callout-note}
# 这是一个提示信息。Quarto 会自动给它加个 ℹ️ 图标。
# :::

# %% [markdown]
# ::: {.callout-warning}
# 注意！这里很容易踩坑。
# :::

# %% [markdown]
# ::: {.callout-important}
# 这是非常重要的内容，一定要看！
# :::

# %% [markdown]
# ::: {.callout-caution}
# 小心驶得万年船。
# :::

# %%
def main():
    print("hello world!")

main()
# Out:
# hello world!

# %%
# quarto render .\test.ipynb --to html

# %% [markdown]
# ---
# title: "[填写专题名称]"
# format:
#   html:
#     toc: true
#     theme: cosmo
#     code-copy: true
#   pdf:
#     pdf-engine: xelatex
#     documentclass: article
# ---
#
# # 💡 专题知识点概览
#
# ::: {.callout-note}
# ### 核心定义
# 在此简要描述该算法。例如：**滑动窗口**主要用于处理数组或字符串中的子序列问题，将 $O(n^2)$ 的复杂度降低到 $O(n)$。
# :::
#
# ::: {.callout-tip}
# ### 关键公式与技巧
# * 技巧 1：[如：左右指针的移动逻辑]
# * 技巧 2：[如：窗口更新的顺序]
# :::
#
# ---

# %% [markdown]
# ## 📝 题目 [编号]：[题目名称]
#
# ::: {.callout-caution}
# ### 题目要求
# **描述**：[在此粘贴题目简述]
#
# **输入输出示例**：
# * **输入**：`nums = [1,3,-1,3,5,3], k = 3`
# * **输出**：`[3,3,5,5]`
# :::

# %% [markdown]
# ::: {.callout-important}
# ### 💡 思路讲解与复杂度分析
# **核心思路**：
# 1. [步骤一：描述如何初始化]
# 2. [步骤二：描述循环中的逻辑]
#
# **复杂度分析**：
# * **时间复杂度**：$O(n)$
# * **空间复杂度**：$O(k)$
# :::
#
# ---
