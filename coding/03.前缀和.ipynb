# %% [markdown]
# ---
# title: "前缀和+差分"
# format:
#   html:
#     embed-resources: true
#     toc: true
#     theme: cosmo
#     code-copy: true
#   pdf:
#     pdf-engine: xelatex
#     documentclass: article
# ---
